# %% [markdown]
# # Instructor-led Lab: Advanced Data Manipulation     &#x1f4ca;
#
# In this assignment, we will go over the new skills in data manipulation with the *piping* expression! <br>
#
# ## Sorting and Ordering Data <br>
#
# We will go over sorting, ordering, and filtering data with some more advanced techniques and piping expressions! <br>

# %% [markdown]
# Let's begin by importing the modules

# %%
import os
import numpy as np  #Imports the "numpy" package
import pandas as pd  #Imports the "pandas" package

# %% [markdown]
# Now let's make sure that we are in the correct working directory

# %%
#Prints the current working directory

os.getcwd()
# Out:
# '/home/school/Documents/python/week_8'

# %% [markdown]
# Sweet! Looks like we are already in the correct working directory! <br>
# Now let's load in the data for the lab. We will be using the "github_teams" data provided:

# %%
#Reads in a .csv file

github_teams = pd.read_csv("data/github_teams.csv")

#Quick Inspect

github_teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name_h                    608 non-null    object
#  1   Team_type                 608 non-null    object
#  2   Team_size_class           608 non-null    object
#  3   human_members_count       608 non-null    int64
#  4   bot_members_count         608 non-null    int64
#  5   human_work                608 non-null    int64
#  6   work_per_human            608 non-null    float64
#  7   human_gini                608 non-null    float64
#  8   human_Push                608 non-null    int64
#  9   human_IssueComments       608 non-null    int64
#  10  human_PRReviewComment     608 non-null    int64
#  11  human_MergedPR            608 non-null    int64
#  12  bot_work                  608 non-null    int64
#  13  bot_Push                  608 non-null    int64
#  14  bot_IssueComments         608 non-null    int64
#  15  bot_PRReviewComment       608 non-null    int64
#  16  bot_MergedPR              608 non-null    int64
#  17  eval_survival_day_median  303 non-null    float64
#  18  issues_count              303 non-null    float64
# dtypes: float64(4), int64(12), object(3)
# memory usage: 90.4+ KB

# %% [markdown]
# Awesome! Now we can see that the "github_teams" dataset has successfully been read into python! <br>
# Now let's start working with the data:

# %%
#Selects/Filters the columns with the respective names

(github_teams
.filter(["Team_type","human_work","work_per_human"]))
# Out:
#      Team_type  human_work  work_per_human
# 0    human-bot          66       33.000000
# 1        human          62       31.000000
# 2        human         211       30.142857
# 3    human-bot       14579       62.303419
# 4    human-bot        1625       42.763158
# ..         ...         ...             ...
# 603  human-bot         855      285.000000
# 604      human          63       31.500000
# 605      human          26        5.200000
# 606      human          13        2.600000
# 607  human-bot          57       28.500000
#
# [608 rows x 3 columns]

# %%
# Select columns that end in the letter "t"

(github_teams
.filter(regex="t$"))
# Out:
#      human_members_count  bot_members_count  human_PRReviewComment  \
# 0                      2                  1                      4
# 1                      2                  0                      0
# 2                      7                  0                      1
# 3                    234                 12                   1170
# 4                     38                  8                    152
# ..                   ...                ...                    ...
# 603                    3                  1                    373
# 604                    2                  0                      0
# 605                    5                  0                      2
# 606                    5                  0                      1
# 607                    2                  1                      1
#
#      bot_PRReviewComment  issues_count
# 0                      0           8.0
# 1                      0           NaN
# 2                      0          46.0
# 3                      0        4757.0
# 4                      0         777.0
# ..                   ...           ...
# 603                    0           NaN
# 604                    0           NaN
# 605                    0           NaN
# 606                    0          10.0
# 607                    1          26.0
#
# [608 rows x 5 columns]

# %%
#Sorts the data in descending order using the "Team_size_class" column

(github_teams
.sort_values(by=("Team_size_class"), ascending=False))
# Out:
#                                             name_h  Team_type Team_size_class  \
# 0    _1bqaxzCk0sfQaunsjeViQ/RCEZ3CASdLXbstu9y2JQ7Q  human-bot           Small
# 274  I1zTLQ0sX0_e1IKG0DL4FQ/1obWttaaw8DkHzSckiVWpw      human           Small
# 326  kRXHmTG1hg25Ms4CoQXuPA/ZDjGaeDQ3pjmkpwswPrEdA      human           Small
# 323  kozDEuBo0KKt8iyeAtO7pw/Khx_dnicluL6V8QNDEKmVQ      human           Small
# 320  kcU_qvEH_y-BumXu1QpNnQ/FL4dW60P1hcLJtWhNFzrkw      human           Small
# ..                                             ...        ...             ...
# 439  ReeJIVTm1BiV_SO5tNDVFA/0DyNJHtC341DeboKhr6ZAw  human-bot           Large
# 441  ReeJIVTm1BiV_SO5tNDVFA/ZfIj2C4Weg8to684MM7PGA  human-bot           Large
# 448  ROWwIEddQryJzc7vl7nTWQ/_GEQzVeMWyYnaL12CEJ2-g      human           Large
# 455  sdJYSIlyI8h0ITiqLCLVvw/m4OHr6Thm04-BYsBZmXGkQ  human-bot           Large
# 220  f7Eo21MyQpwfg3Jz92nq7w/R_qMhRMlg0dHK6WXnc12KA  human-bot           Large
#
#      human_members_count  bot_members_count  human_work  work_per_human  \
# 0                      2                  1          66       33.000000
# 274                    2                  0          22       11.000000
# 326                    2                  0          29       14.500000
# 323                    3                  0         103       34.333333
# 320                    2                  0          28       14.000000
# ..                   ...                ...         ...             ...
# 439                   10                  1         693       69.300000
# 441                   15                  2        2211      147.400000
# 448                   10                  0         186       18.600000
# 455                    7                  1         590       84.285714
# 220                    8                  1          90       11.250000
#
#      human_gini  human_Push  human_IssueComments  human_PRReviewComment  \
# 0      0.287879          29                   33                      4
# 274    0.181818          22                    0                      0
# 326    0.258621          29                    0                      0
# 323    0.362460         101                    2                      0
# 320    0.000000          28                    0                      0
# ..          ...         ...                  ...                    ...
# 439    0.578211          97                  559                     37
# 441    0.544068         214                 1312                    685
# 448    0.553763         149                   36                      1
# 455    0.511864         240                   82                    268
# 220    0.380556          54                   33                      3
#
#      human_MergedPR  bot_work  bot_Push  bot_IssueComments  \
# 0                 0        43         0                 43
# 274               0         0         0                  0
# 326               0         0         0                  0
# 323               0         0         0                  0
# 320               0         0         0                  0
# ..              ...       ...       ...                ...
# 439               0      1000       997                  3
# 441               0        50         0                 47
# 448               0         0         0                  0
# 455               0        14         0                 14
# 220               0        25         0                 25
#
#      bot_PRReviewComment  bot_MergedPR  eval_survival_day_median  issues_count
# 0                      0             0                      87.0           8.0
# 274                    0             0                       NaN           NaN
# 326                    0             0                       NaN           NaN
# 323                    0             0                       NaN           NaN
# 320                    0             0                       NaN           NaN
# ..                   ...           ...                       ...           ...
# 439                    0             0                      91.0         130.0
# 441                    3             0                       9.0           6.0
# 448                    0             0                      64.0          17.0
# 455                    0             0                       7.0           7.0
# 220                    0             0                       NaN           NaN
#
# [608 rows x 19 columns]

# %%
#Sorts the data in descending order using the "human_work" column

(github_teams
.sort_values(by=("human_work"), ascending=False))
# Out:
#                                             name_h  Team_type Team_size_class  \
# 230  FAhkB4rsocfDW0vrM8U8NA/x48tfDezFe8qzB_Gbe_tMA  human-bot           Large
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 534  vjYCi8YxMpUj_LaqRdiCXw/wPCNTC9mtdWb8MKJVr439g      human           Large
# 37   0YuGJKD19yHae4I2X8Vi3Q/gWpl7HC8bRe4tH8S7ASf9w  human-bot           Large
# 89   5Is-_ie16OEGmW1arZm8qg/8UeSk2P76pTG7pPLtxsHTQ  human-bot           Large
# ..                                             ...        ...             ...
# 180  CWghQeCv2EVQNS-Wb6M_EA/N0nGHZBEl2y-GPcfOGvytQ      human           Small
# 25   0Jb-T8Py7O9d0fsJhO-Fpw/9CTgx1gdJFtNJTvxhIZZUA  human-bot           Small
# 237  FJmB0zbVT0ileOMUPtWRIQ/v2hyhTxDNjcQKAdrTbpb-g  human-bot           Small
# 60   3VFbLRx-am2PA7KH0P_qQQ/80s2Rw6RQNhfx0QKHYY0Og  human-bot           Small
# 26   0Jb-T8Py7O9d0fsJhO-Fpw/D-kWwOGGgx1lyqq0SaB3Hg  human-bot           Small
#
#      human_members_count  bot_members_count  human_work  work_per_human  \
# 230                   54                  1       15448      286.074074
# 3                    234                 12       14579       62.303419
# 534                   28                  0       10705      382.321429
# 37                    84                  1        9644      114.809524
# 89                    17                  4        7412      436.000000
# ..                   ...                ...         ...             ...
# 180                    2                  0           9        4.500000
# 25                     2                  1           8        4.000000
# 237                    3                  1           8        2.666667
# 60                     2                  1           7        3.500000
# 26                     2                  1           2        1.000000
#
#      human_gini  human_Push  human_IssueComments  human_PRReviewComment  \
# 230    0.625010        2056                 7944                   5382
# 3      0.738342        1942                11430                   1170
# 534    0.743961        4230                 2337                   3997
# 37     0.807448        1095                 5073                   3365
# 89     0.439621        4182                 1257                   1917
# ..          ...         ...                  ...                    ...
# 180    0.166667           7                    2                      0
# 25     0.125000           6                    1                      1
# 237    0.416667           8                    0                      0
# 60     0.071429           6                    1                      0
# 26     0.000000           2                    0                      0
#
#      human_MergedPR  bot_work  bot_Push  bot_IssueComments  \
# 230              66       282         0                282
# 3                37      1972         0               1972
# 534             141         0         0                  0
# 37              111       329         0                329
# 89               56       358         5                202
# ..              ...       ...       ...                ...
# 180               0         0         0                  0
# 25                0        13        13                  0
# 237               0        24        24                  0
# 60                0         5         3                  2
# 26                0        69        40                 29
#
#      bot_PRReviewComment  bot_MergedPR  eval_survival_day_median  issues_count
# 230                    0             0                       9.0        1015.0
# 3                      0             0                       1.0        4757.0
# 534                    0             0                       4.0          21.0
# 37                     0             0                       2.0        2993.0
# 89                   151             0                       2.0         495.0
# ..                   ...           ...                       ...           ...
# 180                    0             0                       NaN           NaN
# 25                     0             0                       NaN           NaN
# 237                    0             0                       NaN           NaN
# 60                     0             0                       NaN           NaN
# 26                     0             0                       NaN           NaN
#
# [608 rows x 19 columns]

# %%
#Sorts the data in descending order using the "work_per_human" column

(github_teams
.sort_values(by=("work_per_human"), ascending=False))
# Out:
#                                             name_h  Team_type Team_size_class  \
# 559  WLaEz_1Nf-YWzHZa8bBgAA/pLoAhZ1cbPT38VYoSdXGmg      human           Small
# 209  eIPosZ68E2LjtaixYK65EQ/0Rp6D1ZR1w4YspfD1H-PfA  human-bot           Small
# 268  hXoZRbHPbVxh--funPXSiw/iNU0l_SpKVjGfHOp8vUt8w  human-bot           Small
# 89   5Is-_ie16OEGmW1arZm8qg/8UeSk2P76pTG7pPLtxsHTQ  human-bot           Large
# 88   572IwNWvcAWEW0XmL9kzxg/dsdz8N9WSpmtzc0q9veAhQ  human-bot           Large
# ..                                             ...        ...             ...
# 497  tzOdbObpFg-vSbow3RBUBg/siHdJSIMcipwQwok068VBg      human           Large
# 600  ZPbZUFullnQ00GjBX1RaUQ/fR24eYhOcMGsDUKZIYFXeg      human          Medium
# 484  TcHjRpnzF2qIwAEHHGAFAA/siHdJSIMcipwQwok068VBg      human           Large
# 292  ilEEnZRNdUqNk7tvvGBo1Q/8xHANrgyHiFV3TuhcqwrpQ      human           Large
# 26   0Jb-T8Py7O9d0fsJhO-Fpw/D-kWwOGGgx1lyqq0SaB3Hg  human-bot           Small
#
#      human_members_count  bot_members_count  human_work  work_per_human  \
# 559                    3                  0        3040     1013.333333
# 209                    3                  1        1639      546.333333
# 268                    2                  2         910      455.000000
# 89                    17                  4        7412      436.000000
# 88                     9                  1        3774      419.333333
# ..                   ...                ...         ...             ...
# 497                  115                  0         286        2.486957
# 600                    6                  0          14        2.333333
# 484                   68                  0         155        2.279412
# 292                    8                  0          14        1.750000
# 26                     2                  1           2        1.000000
#
#      human_gini  human_Push  human_IssueComments  human_PRReviewComment  \
# 559    0.292105         434                 2606                      0
# 209    0.413260        1114                  283                    223
# 268    0.065934         207                  369                    334
# 89     0.439621        4182                 1257                   1917
# 88     0.504151        2733                  958                      5
# ..          ...         ...                  ...                    ...
# 497    0.322043         286                    0                      0
# 600    0.190476          13                    1                      0
# 484    0.345446         155                    0                      0
# 292    0.250000          14                    0                      0
# 26     0.000000           2                    0                      0
#
#      human_MergedPR  bot_work  bot_Push  bot_IssueComments  \
# 559               0         0         0                  0
# 209              19       156         0                156
# 268               0       114         0                114
# 89               56       358         5                202
# 88               78       575         0                575
# ..              ...       ...       ...                ...
# 497               0         0         0                  0
# 600               0         0         0                  0
# 484               0         0         0                  0
# 292               0         0         0                  0
# 26                0        69        40                 29
#
#      bot_PRReviewComment  bot_MergedPR  eval_survival_day_median  issues_count
# 559                    0             0                       3.0         365.0
# 209                    0             0                      21.0         204.0
# 268                    0             0                       4.0          64.0
# 89                   151             0                       2.0         495.0
# 88                     0             0                      27.0        1210.0
# ..                   ...           ...                       ...           ...
# 497                    0             0                       NaN           NaN
# 600                    0             0                       NaN           NaN
# 484                    0             0                       NaN           NaN
# 292                    0             0                       NaN           NaN
# 26                     0             0                       NaN           NaN
#
# [608 rows x 19 columns]

# %%
#Selects the "human-bot" teams that have a "bot_members_count" greater than or equal to 3

(github_teams
.query("Team_type == 'human-bot' & bot_members_count >= 3"))
# Out:
#                                            name_h  Team_type Team_size_class  \
# 3   _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4   _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# 89  5Is-_ie16OEGmW1arZm8qg/8UeSk2P76pTG7pPLtxsHTQ  human-bot           Large
#
#     human_members_count  bot_members_count  human_work  work_per_human  \
# 3                   234                 12       14579       62.303419
# 4                    38                  8        1625       42.763158
# 89                   17                  4        7412      436.000000
#
#     human_gini  human_Push  human_IssueComments  human_PRReviewComment  \
# 3     0.738342        1942                11430                   1170
# 4     0.666607         203                 1270                    152
# 89    0.439621        4182                 1257                   1917
#
#     human_MergedPR  bot_work  bot_Push  bot_IssueComments  \
# 3               37      1972         0               1972
# 4                0       302         0                302
# 89              56       358         5                202
#
#     bot_PRReviewComment  bot_MergedPR  eval_survival_day_median  issues_count
# 3                     0             0                       1.0        4757.0
# 4                     0             0                       2.0         777.0
# 89                  151             0                       2.0         495.0

# %%
#Selects the "human" teams that are large and have a 'human-gini' value greater than or equal to 0.75

(github_teams
.query("Team_type == 'human' & Team_size_class == 'Large' & human_gini >= 0.75"))
# Out:
#                                             name_h Team_type Team_size_class  \
# 138  ASYGR96YA91p3z7MNKjZCA/IB2pZ8ygcvNnlxUdysjSFA     human           Large
# 285  IiUao8vA_zm_uEIVVLI-Sw/91ya8vlSP8qgwCllH_6BSw     human           Large
# 505  uLHPO58cQefwrJUbyhYOKQ/7YWOP8uDEeKDHQMWKqOoYA     human           Large
# 582  y8Jw59EHVSrsluSuhR5okg/V5vb074jNkzg4YCKforX1Q     human           Large
#
#      human_members_count  bot_members_count  human_work  work_per_human  \
# 138                   12                  0        1655      137.916667
# 285                   25                  0        3599      143.960000
# 505                   48                  0        5748      119.750000
# 582                    8                  0         277       34.625000
#
#      human_gini  human_Push  human_IssueComments  human_PRReviewComment  \
# 138    0.799446         793                  684                    178
# 285    0.863507        1249                 2350                      0
# 505    0.782040        1715                 3891                    142
# 582    0.781137         275                    2                      0
#
#      human_MergedPR  bot_work  bot_Push  bot_IssueComments  \
# 138               0         0         0                  0
# 285               0         0         0                  0
# 505               0         0         0                  0
# 582               0         0         0                  0
#
#      bot_PRReviewComment  bot_MergedPR  eval_survival_day_median  issues_count
# 138                    0             0                       4.0         190.0
# 285                    0             0                       0.0        1245.0
# 505                    0             0                       0.0        1200.0
# 582                    0             0                       NaN           NaN

# %%
#Determines how many teams are in the 'Small' or 'Large' category

(github_teams
.query("Team_size_class != 'Medium'")
.agg({'name_h':("count")})
)
# Out:
# name_h    428
# dtype: int64

# %% [markdown]
# There seems to be 428 teams that are either 'Small' or 'Large'.

# %%
#Determines how many teams are in the 'Small' or 'Large' category with a 'human_gini' 
#value less than or equal to 0.25.


(github_teams
.query("Team_size_class != 'Medium' & human_gini <= 0.25")
.agg({'name_h':("count")})
)
# Out:
# name_h    89
# dtype: int64

# %% [markdown]
# There are 89 teams that are 'Small' or 'Large' with a 'human_gini' values less than or equal to 0.25.

# %%
#Counts how many 'human' teams are in the 'Medium' category

(github_teams
.query("Team_type == 'human' & Team_size_class == 'Medium'")
.agg({'name_h':("count")})
)
# Out:
# name_h    96
# dtype: int64

# %% [markdown]
# There are 96 'Human' teams that are 'medium' sized.

# %%
#Saves the 'Team_size_class' and 'work_per_human' columns into a new dataframe

new_github_teams = (github_teams
.filter(["Team_size_class","work_per_human"]))

#Print to confirm

new_github_teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Team_size_class  608 non-null    object
#  1   work_per_human   608 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 9.6+ KB

# %%
#Renames the columns in the dataframe:

# 'human_gini' -> 'work_inequality'
# 'eval_survival_day_median' -> 'issue_resolution_time'


github_teams_rename = (github_teams
.rename(columns={
    'human_gini':'work_inequality',
    'eval_survival_day_median':'issue_resolution_time'
}))

#Print to confirm

github_teams_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name_h                 608 non-null    object
#  1   Team_type              608 non-null    object
#  2   Team_size_class        608 non-null    object
#  3   human_members_count    608 non-null    int64
#  4   bot_members_count      608 non-null    int64
#  5   human_work             608 non-null    int64
#  6   work_per_human         608 non-null    float64
#  7   work_inequality        608 non-null    float64
#  8   human_Push             608 non-null    int64
#  9   human_IssueComments    608 non-null    int64
#  10  human_PRReviewComment  608 non-null    int64
#  11  human_MergedPR         608 non-null    int64
#  12  bot_work               608 non-null    int64
#  13  bot_Push               608 non-null    int64
#  14  bot_IssueComments      608 non-null    int64
#  15  bot_PRReviewComment    608 non-null    int64
#  16  bot_MergedPR           608 non-null    int64
#  17  issue_resolution_time  303 non-null    float64
#  18  issues_count           303 non-null    float64
# dtypes: float64(4), int64(12), object(3)
# memory usage: 90.4+ KB

# %% [markdown]
# # References
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.agg.html
